# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\CVR\Downloads\weight-height.csv')

df = df.drop('Gender',axis=1)

# %%
from sklearn.linear_model import LinearRegression

lgr = LinearRegression()

from sklearn.model_selection import train_test_split

# %%
df
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df['Height'],df['Weight'],test_size=0.2,random_state=42)

# %%
import numpy as np

X_train = np.reshape(X_train,(-1,1))
X_test = np.reshape(X_test,(-1,1))

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-1.29189725],
#        [ 2.16821664],
#        [ 0.5586044 ],
#        ...,
#        [-0.52899659],
#        [ 0.70596411],
#        [ 0.31963251]])

# %%
Y_train
# Out:
# 9254    120.681907
# 1561    209.373126
# 1670    200.877279
# 6087    134.342745
# 6669    160.201031
#            ...
# 5734    139.223151
# 5191     90.728561
# 5390    156.800504
# 860     179.386817
# 7270    150.380597
# Name: Weight, Length: 8000, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  10000 non-null  float64
#  1   Weight  10000 non-null  float64
# dtypes: float64(2)
# memory usage: 156.4 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df,x='Height',y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
X_train.shape
# Out:
# (8000, 1)

# %%
lgr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lgr.score(X_test,Y_test)
# Out:
# 0.8574488157962482

# %%
y_predicted = lgr.predict(X_test)

sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(X_train,Y_train,c='g',label='Data Points')
plt.plot(X_test,y_predicted,c='r',label='Best fit')
plt.legend()

# %%
type(df['Weight'])
# Out:
# pandas.core.series.Series
