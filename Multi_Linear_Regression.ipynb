# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
import seaborn as sns

# %%
data = {
    'Size': [1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200],
    'Bedrooms': [3, 3, 3, 4, 4, 4, 5, 5],
    'Age': [10, 15, 10, 20, 30, 15, 20, 25],
    'Price': [300000, 320000, 340000, 360000, 400000, 370000, 420000, 430000]
}

# %%
df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Size      8 non-null      int64
#  1   Bedrooms  8 non-null      int64
#  2   Age       8 non-null      int64
#  3   Price     8 non-null      int64
# dtypes: int64(4)
# memory usage: 388.0 bytes

# %%
df.describe()
# Out:
#               Size  Bedrooms       Age         Price
# count     8.000000  8.000000   8.00000       8.00000
# mean   1850.000000  3.875000  18.12500  367500.00000
# std     244.948974  0.834523   7.03943   46827.95258
# min    1500.000000  3.000000  10.00000  300000.00000
# 25%    1675.000000  3.000000  13.75000  335000.00000
# 50%    1850.000000  4.000000  17.50000  365000.00000
# 75%    2025.000000  4.250000  21.25000  405000.00000
# max    2200.000000  5.000000  30.00000  430000.00000

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df.drop('Price',axis=1),df.Price,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#    Size  Bedrooms  Age
# 0  1500         3   10
# 7  2200         5   25
# 2  1700         3   10
# 4  1900         4   30
# 3  1800         4   20
# 6  2100         5   20

# %%
X_test
# Out:
#    Size  Bedrooms  Age
# 1  1600         3   15
# 5  2000         4   15

# %%
Y_train
# Out:
# 0    300000
# 7    430000
# 2    340000
# 4    400000
# 3    360000
# 6    420000
# Name: Price, dtype: int64

# %%
Y_test
# Out:
# 1    320000
# 5    370000
# Name: Price, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.5210964331075817

# %%
import seaborn as sns

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
model.intercept_
# Out:
# 33576.017130618275

# %%
model.coef_
# Out:
# array([  182.01284797, -6252.67665953,  1391.86295503])

# %%
y_pred = model.predict(X_test)

# %%
Y_test
# Out:
# 1    320000
# 5    370000
# Name: Price, dtype: int64

# %%
y_pred
# Out:
# array([326916.4882227 , 393468.95074946])

# %%
mean_squared_error(Y_test,y_pred)
# Out:
# 299314729.30776143

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.5210964331075817

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# 15192.719486081274

# %%
model.predict([[1200,2,4]])
# Out:
# C:\Users\bandi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([245053.53319058])

# %% [markdown]
# ## for Two variables

# %%
X = df[['Age','Bedrooms']]

# %%
Y = df['Price']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.9598782246434869

# %%
model.coef_
# Out:
# array([ 1898.73417722, 40632.91139241])

# %%
model.intercept_
# Out:
# 176075.9493670886

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(Y_test,y_pred)
# Out:
# 25076109.597820688

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# 4683.544303797447

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.9598782246434869

# %%
model.predict([[1500,4]])
# Out:
# C:\Users\bandi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3186708.8607595])

# %% [markdown]
# # for One Variable

# %%
X = df[['Bedrooms']]

# %%
Y = df['Price']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.975

# %%
model.coef_
# Out:
# array([52500.])

# %%
model.intercept_
# Out:
# 165000.0

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(Y_test,y_pred)
# Out:
# 15625000.0

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# 3750.0

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.975

# %%
model.predict([[5]])
# Out:
# C:\Users\bandi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([427500.])

# %%
wine_path = r"C:\Users\bandi\Downloads\wine.csv"

# %%
wine_df = pd.read_csv(wine_path)

# %%
wine_df.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %%
wind_df['Wine'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression(max_iter=10000)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(wine_df.drop('Wine',axis=1),wine_df.Wine,test_size=0.2,random_state=42)

# %%
lg.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
lg.score(X_test,Y_test)
# Out:
# 1.0

# %%
y_pred = lg.predict(X_test)

# %%
r2_score(Y_test,y_pred)
# Out:
# 1.0

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.8825140263270385

# %%
y_pred = model.predict(X_test)

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.8825140263270385

# %% [markdown]
# ## Regularisation

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
rg = Ridge(alpha=0.6)

# %%
rg.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.6)

# %%
rg.score(X_test,Y_test)
# Out:
# 0.8830632417577553

# %%
ls = Lasso(alpha=0.1)

# %%
ls.fit(X_train,Y_train)
# Out:
# Lasso(alpha=0.1)

# %%
ls.score(X_test,Y_test)
# Out:
# 0.8402544154076075
